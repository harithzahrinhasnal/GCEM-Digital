# %%
import pandas as pd

# Specify the path to the Excel file
file_path = 'Input_data.xlsx'

# Read the Excel file, specifying the sheet name as 'Data'
df = pd.read_excel(file_path, sheet_name='Data', dtype={'Price Date': str})

# Convert all data in the DataFrame to strings
df = df.astype(str)


# Display the data
print(df)

# Print the columns of the DataFrame
print("Columns in the 'Data' sheet:")
print(df.columns)

# %%
# Loop through the DataFrame and print the data for 'Price Date' and 'Expiry' for each row
for i in range(len(df)):
    price_date = df.iloc[i, 3]  # 'Price Date' is at index 3
    expiry = df.iloc[i, 4]     # 'Expiry' is at index 4

# %%
import pandas as pd

# Specify the path to the Excel file
file_path = 'Input_data.xlsx'

# Read the Excel file, specifying the sheet name as 'Data'
df = pd.read_excel(file_path, sheet_name='Data', dtype={'Price Date': str})

# Convert all data in the DataFrame to strings
df = df.astype(str)

# Display the data
print("Original Data:")
print(df)

# Loop through each row to input new values for specified columns
for index, row in df.iterrows():
    print(f"\nFor row {index}:")
    
    # Ask for user input for each column one by one
    new_77_PutPremium = 77
    df.at[index, '77-PutPremium'] = new_77_PutPremium
    
    new_64_PutPremium = 64
    df.at[index, '64-PutPremium'] = new_64_PutPremium
    
    new_10_OTMF_CallPremium = 10
    df.at[index, '10%OTMF-CallPremium'] = new_10_OTMF_CallPremium
    
    new_20_OTMF_CallPremium = 20
    df.at[index, '20%OTMF-CallPremium'] = new_20_OTMF_CallPremium
    
    new_30_OTMF_CallPremium = 30
    df.at[index, '30%OTMF-CallPremium'] = new_30_OTMF_CallPremium
    
    new_77_PutVols = 77
    df.at[index, '77-PutVols'] = new_77_PutVols
    
    new_64_PutVols = 64
    df.at[index, '64-PutVols'] = new_64_PutVols
    
    new_10_OTMF_CallVols = 10
    df.at[index, '10%OTMF-CallVols'] = new_10_OTMF_CallVols
    
    new_20_OTMF_CallVols = 20
    df.at[index, '20%OTMF-CallVols'] = new_20_OTMF_CallVols
    
    new_30_OTMF_CallVols = 30
    df.at[index, '30%OTMF-CallVols'] = new_30_OTMF_CallVols
    
    new_Swap_Ref = 'swap'
    df.at[index, 'Swap Ref'] = new_Swap_Ref

# Display the updated data
print("\nUpdated Data:")
print(df)

# Save the updated DataFrame to a new Excel file
output_file_path = 'Updated_data.xlsx'
df.to_excel(output_file_path, index=False)

print(f"Updated data has been saved to {output_file_path}")

# %%
import datetime
import openpyxl
import os
import pyautogui
import time
import pyperclip
from tabulate import tabulate  
from threading import Thread
from collections.abc import Mapping
import openpyxl
import subprocess
import re
import ctypes 
import pymsteams
import pandas as pd
from itertools import product


Monitor = 'Office Monitor'
if Monitor == 'Office Monitor': 
    search_bar = [44, 112]
    time_input = [640, 300]
    date_input = [250, 300]
    call_put = [250, 450]
    strike = [250, 500]
    moneyness = [370, 500]
    tenure = [250, 470]
    unit_barrel = [250, 520]
    vol = [250, 660]
    swap_ref = [250, 700]
    premium = [250, 820]
    


time.sleep(5)
pyautogui.hotkey('ctrl', 't')

time.sleep(2)
pyautogui.moveTo(search_bar, duration = 0.5)
pyautogui.press('enter')
pyautogui.write('OVML APO')
pyautogui.press('enter')
time.sleep(9)

pyautogui.moveTo(time_input, duration = 0.5)
pyautogui.click()
pyautogui.write('21:00')

pyautogui.moveTo(unit_barrel, duration = 0.5)
pyautogui.click()
pyautogui.write('1')

pyautogui.moveTo(date_input, duration = 0.5)
pyautogui.click()
pyautogui.write('060124')
time.sleep(1)
pyautogui.hotkey('enter')

pyautogui.moveTo(tenure, duration = 0.5)
pyautogui.click()
pyautogui.write('Jan24')
time.sleep(1)
pyautogui.hotkey('enter')

pyautogui.moveTo(call_put, duration = 0.5)
pyautogui.click()
pyautogui.write('call')
pyautogui.hotkey('enter')

pyautogui.moveTo(strike, duration = 0.5)
pyautogui.click()
pyautogui.write('77')

pyautogui.moveTo(moneyness, duration = 0.5)
pyautogui.click()
pyautogui.hotkey('ctrl', 'c')
print(pyperclip.paste())

pyautogui.moveTo(vol, duration = 0.5)
pyautogui.click()
pyautogui.hotkey('ctrl', 'c')
print(pyperclip.paste())

pyautogui.moveTo(swap_ref, duration = 0.5)
pyautogui.click()
pyautogui.hotkey('ctrl', 'c')
print(pyperclip.paste())

pyautogui.moveTo(premium, duration = 0.5)
pyautogui.click()
pyautogui.hotkey('ctrl', 'c')
print(pyperclip.paste())

# %%
time.sleep(2)
x_input = [400, 300]
pyautogui.moveTo(x_input, duration = 0.5)
pyautogui.click()
pyautogui.write('test')

# %%
import pandas as pd
import pyautogui
import time
import pyperclip
from tabulate import tabulate  
from threading import Thread
from collections.abc import Mapping
import re
import ctypes 
import pandas as pd
from itertools import product


Monitor = 'Office Monitor'
if Monitor == 'Office Monitor': 
    search_bar = [44, 112]
    time_input = [400, 300]
    date_input = [260, 300]
    call_put = [250, 450]
    strike = [250, 500]
    moneyness = [365, 500]
    tenure = [250, 470]
    unit_barrel = [250, 520]
    vol = [250, 660]
    swap_ref = [250, 700]
    premium = [250, 820]
    
#Sheetname 
Sheetname = 'Mar23'   
#Puts
Put_1 = '77'
Put_2 = '64'
#calls
Call_1 = '10%OTMF'
Call_2 = '20%OTMF'
Call_3 = '30%OTMF'
Call_4 = '40%OTMF'
Call_5 = '50%OTMF'

# Specify the path to the Excel file
file_path = 'Input_data_Real.xlsx'

# Read the Excel file, specifying the sheet name as 'Data'
df = pd.read_excel(file_path, sheet_name=Sheetname, dtype={'Price Date': str})

# Convert all data in the DataFrame to strings
df = df.astype(str)

# Display the data
print("Original Data:")
print(df)

time.sleep(5)
pyautogui.hotkey('ctrl', 't')

time.sleep(2)
pyautogui.moveTo(search_bar, duration = 0.5)
pyautogui.press('enter')
pyautogui.write('OVML APO')
pyautogui.press('enter')
time.sleep(9)

pyautogui.moveTo(time_input, duration = 0.5)
pyautogui.click()
pyautogui.write('21:00')

pyautogui.moveTo(unit_barrel, duration = 0.5)
pyautogui.click()
pyautogui.write('1')

def checklevel(IN):
    if IN == '0' or not re.search(r"\d+\.\d+", IN):
        return 0
    numbers = re.findall(r"\d+\.\d+", IN)
    return float(numbers[0])

def extract_percentage(output):
    return output.split('%')[0]




# Loop through each row to input new values for specified columns
for index, row in df.iterrows():
    pyautogui.moveTo(date_input, duration = 0.5)
    pyautogui.click()
    time.sleep(1)
    print(str(df.iloc[index, 3]))
    pyautogui.write(str(df.iloc[index, 3]))
    pyautogui.hotkey('enter')

    

    pyautogui.moveTo(tenure, duration = 0.5)
    pyautogui.click()
    pyautogui.write(str(df.iloc[index, 4]))
    time.sleep(2)
    pyautogui.hotkey('enter')
    pyautogui.hotkey('enter')
    
   
    pyautogui.moveTo(call_put, duration = 0.5)
    pyautogui.click()
    pyautogui.write('put')
    time.sleep(1)
    pyautogui.hotkey('enter')


    pyautogui.moveTo(strike, duration = 0.5)
    pyautogui.click()
    pyautogui.write(Put_1)
    pyautogui.hotkey('enter')
    time.sleep(1)
    pyautogui.moveTo(premium, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    new_77_PutPremium = checklevel(pyperclip.paste())
    df.at[index, '77-PutPremium'] = new_77_PutPremium

    pyautogui.moveTo(vol, duration = 0.5)
    pyautogui.click()
    time.sleep(1)
    pyautogui.hotkey('ctrl', 'c')
    df.at[index, '77-PutVols'] = extract_percentage(pyperclip.paste())
    

    pyautogui.moveTo(strike, duration = 0.5)
    pyautogui.click()
    pyautogui.write(Put_2)
    pyautogui.hotkey('enter')
    time.sleep(1)
    pyautogui.moveTo(premium, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    new_64_PutPremium = checklevel(pyperclip.paste())
    df.at[index, '64-PutPremium'] = new_64_PutPremium

    pyautogui.moveTo(vol, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    df.at[index, '64-PutVols'] = extract_percentage(pyperclip.paste())


    pyautogui.moveTo(call_put, duration = 0.5)
    pyautogui.click()
    pyautogui.write('call')
    time.sleep(1)
    pyautogui.hotkey('enter')
    

    pyautogui.moveTo(moneyness, duration = 0.5)
    pyautogui.click()
    pyautogui.write(Call_1)
    pyautogui.hotkey('enter')
    time.sleep(1)
    pyautogui.moveTo(premium, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    
    new_10_OTMF_CallPremium = checklevel(pyperclip.paste())
    df.at[index, '10%OTMF-CallPremium'] = new_10_OTMF_CallPremium

    pyautogui.moveTo(vol, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    df.at[index, '10%OTMF-CallVols'] = extract_percentage(pyperclip.paste())

    pyautogui.moveTo(moneyness, duration = 0.5)
    pyautogui.click()
    pyautogui.write(Call_2)
    pyautogui.hotkey('enter')
    time.sleep(1)
    pyautogui.moveTo(premium, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    
    
    new_20_OTMF_CallPremium = checklevel(pyperclip.paste())
    df.at[index, '20%OTMF-CallPremium'] = new_20_OTMF_CallPremium

    pyautogui.moveTo(vol, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    df.at[index, '20%OTMF-CallVols'] = extract_percentage(pyperclip.paste())

    pyautogui.moveTo(moneyness, duration = 0.5)
    pyautogui.click()
    pyautogui.write(Call_3)
    pyautogui.hotkey('enter')
    time.sleep(1)
    pyautogui.moveTo(premium, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    
    new_30_OTMF_CallPremium = checklevel(pyperclip.paste())
    df.at[index, '30%OTMF-CallPremium'] = new_30_OTMF_CallPremium

    pyautogui.moveTo(vol, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    df.at[index, '30%OTMF-CallVols'] = extract_percentage(pyperclip.paste())

    pyautogui.moveTo(moneyness, duration = 0.5)
    pyautogui.click()
    pyautogui.write(Call_4)
    pyautogui.hotkey('enter')
    time.sleep(1)
    pyautogui.moveTo(premium, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    
    new_40_OTMF_CallPremium = checklevel(pyperclip.paste())
    df.at[index, '40%OTMF-CallPremium'] = new_40_OTMF_CallPremium

    pyautogui.moveTo(vol, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    df.at[index, '40%OTMF-CallVols'] = extract_percentage(pyperclip.paste())

    pyautogui.moveTo(moneyness, duration = 0.5)
    pyautogui.click()
    pyautogui.write(Call_5)
    pyautogui.hotkey('enter')
    time.sleep(1)
    pyautogui.moveTo(premium, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    
    new_50_OTMF_CallPremium = checklevel(pyperclip.paste())
    df.at[index, '50%OTMF-CallPremium'] = new_50_OTMF_CallPremium

    pyautogui.moveTo(vol, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    df.at[index, '50%OTMF-CallVols'] = extract_percentage(pyperclip.paste())

    

    pyautogui.moveTo(swap_ref, duration = 0.5)
    pyautogui.click()
    pyautogui.hotkey('ctrl', 'c')
    new_Swap_Ref = pyperclip.paste()
    df.at[index, 'Swap Ref'] = new_Swap_Ref

# Display the updated data
print("\nUpdated Data:")
print(df)

# Save the updated DataFrame to a new Excel file
output_file_path = 'Updated_data.xlsx'
df.to_excel(output_file_path, index=False)

print(f"Updated data has been saved to {output_file_path}")

ctypes.windll.user32.MessageBoxW(0, "Bot is Done!!", "Pricing Bot",  0x1000)
# Out:
# Original Data:
#     No   Time       Asset Price Date Expiry 77-PutPremium 64-PutPremium  \
# 0   42  21:00  CO1 Comdty     021923  Mar23           nan           nan
# 1   43  21:00  CO1 Comdty     022123  Mar23           nan           nan
# 2   44  21:00  CO1 Comdty     022323  Mar23           nan           nan
# 3   45  21:00  CO1 Comdty     022523  Mar23           nan           nan
# 4   46  21:00  CO1 Comdty     022723  Mar23           nan           nan
# 5   47  21:00  CO1 Comdty     030123  Mar23           nan           nan
# 6   48  21:00  CO1 Comdty     030323  Mar23           nan           nan
# 7   49  21:00  CO1 Comdty     030523  Mar23           nan           nan
# 8   50  21:00  CO1 Comdty     030723  Mar23           nan           nan
# 9   51  21:00  CO1 Comdty     030923  Mar23           nan           nan
# 10  52  21:00  CO1 Comdty     031123  Mar23           nan           nan
# 11  53  21:00  CO1 Comdty     031323  Mar23           nan           nan
# ...
